# %% [markdown]
# ## Python and API with registration

# %%
# import libraries for initial set up
import requests
import json
import pandas as pd

# %%
# OS module in Python provides functions for creating and removing a directory (folder),fetching its contents,changing and identifying the current directory"
import os
import shutil
# function to avoid uploading checkpoint files to github
def rm_ipynb_recursively(path):
    try:
        li = os.listdir(path) # Return a list of the entries in the directory given by path.

    except:
        return 0
    
    cnt_removed = 0
    for child in li:
        childpath = os.path.join(path, child)
        if child == '.ipynb_checkpoints':
            shutil.rmtree(childpath)
            cnt_removed += 1
            print('removed', childpath)
        else:
            cnt_removed += rm_ipynb_recursively(childpath)
            
    return cnt_removed

# %%
# to get access to the API you need your credentials
APP_ID = "7c30947d"
APP_KEY = "b4e80c00f3134c320123ded1b36d13fb"

# %%
# Setting up the request URL
api_endpoint = "https://api.edamam.com/api/nutrition-details"

# %%
url = api_endpoint + "?app_id=" + APP_ID + "&app_key=" + APP_KEY

# %%
# post request and its parameters (see documentation of the API website)
# must contain a content type header, title and ingr are mandatory

# %%
headers ={
    'Content-Type':'application/json'
}

# %%
recipe = {
    'title': 'Gin and tonic',
    'ingr':['20ml tonic', '10ml gin']
}

# %%
r=requests.post (url, headers=headers, json=recipe)

# %%
# check request status ok
r.status_code
# Out:
# 200

# %%
# inspect response
gin_info= r.json()
print(json.dumps(gin_info, indent = 4))
# Out:
# {
#     "uri": "http://www.edamam.com/ontologies/edamam.owl#recipe_2d863890d9af44f08c08e600ebf4acba",
#     "yield": 2.0,
#     "calories": 31,
#     "totalWeight": 30.026852159236583,
#     "dietLabels": [
#         "LOW_FAT",
#         "LOW_SODIUM"
#     ],
#     "healthLabels": [
#         "FAT_FREE",
#         "LOW_FAT_ABS",
#         "LOW_POTASSIUM",
#         "KIDNEY_FRIENDLY",
#         "KETO_FRIENDLY",
#         "VEGAN",
#         "VEGETARIAN",
#         "PESCATARIAN",
#         "SPECIFIC_CARBS",
#         "DAIRY_FREE",
#         "GLUTEN_FREE",
#         "WHEAT_FREE",
#         "EGG_FREE",
#         "MILK_FREE",
#         "PEANUT_FREE",
#         "TREE_NUT_FREE",
#         "SOY_FREE",
#         "FISH_FREE",
#         "SHELLFISH_FREE",
#         "PORK_FREE",
#         "RED_MEAT_FREE",
#         "CRUSTACEAN_FREE",
#         "CELERY_FREE",
#         "MUSTARD_FREE",
#         "SESAME_FREE",
#         "LUPINE_FREE",
#         "MOLLUSK_FREE",
#         "NO_OIL_ADDED",
#         "NO_SUGAR_ADDED",
#         "KOSHER",
#         "ALCOHOL_COCKTAIL"
#     ],
#     "cautions": [],
#     "totalNutrients": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 31.735812866587732,
#             "unit": "kcal"
#         },
#         "FAT": {
#             "label": "Total lipid (fat)",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "FASAT": {
#             "label": "Fatty acids, total saturated",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "FAMS": {
#             "label": "Fatty acids, total monounsaturated",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "FAPU": {
#             "label": "Fatty acids, total polyunsaturated",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "CHOCDF": {
#             "label": "Carbohydrate, by difference",
#             "quantity": 1.8151367386349324,
#             "unit": "g"
#         },
#         "FIBTG": {
#             "label": "Fiber, total dietary",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "SUGAR": {
#             "label": "Sugars, total",
#             "quantity": 1.8151367386349324,
#             "unit": "g"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "NA": {
#             "label": "Sodium, Na",
#             "quantity": 2.6631924279971546,
#             "unit": "mg"
#         },
#         "CA": {
#             "label": "Calcium, Ca",
#             "quantity": 0.2062655384812423,
#             "unit": "mg"
#         },
#         "MG": {
#             "label": "Magnesium, Mg",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "K": {
#             "label": "Potassium, K",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "FE": {
#             "label": "Iron, Fe",
#             "quantity": 0.002062655384812423,
#             "unit": "mg"
#         },
#         "ZN": {
#             "label": "Zinc, Zn",
#             "quantity": 0.02062655384812423,
#             "unit": "mg"
#         },
#         "P": {
#             "label": "Phosphorus, P",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A, RAE",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "VITC": {
#             "label": "Vitamin C, total ascorbic acid",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "THIA": {
#             "label": "Thiamin",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "RIBF": {
#             "label": "Riboflavin",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "NIA": {
#             "label": "Niacin",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "VITB6A": {
#             "label": "Vitamin B-6",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "FOLDFE": {
#             "label": "Folate, DFE",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "FOLFD": {
#             "label": "Folate, food",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "FOLAC": {
#             "label": "Folic acid",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "VITB12": {
#             "label": "Vitamin B-12",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "VITD": {
#             "label": "Vitamin D (D2 + D3)",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E (alpha-tocopherol)",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "VITK1": {
#             "label": "Vitamin K (phylloquinone)",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "WATER": {
#             "label": "Water",
#             "quantity": 24.628375806841944,
#             "unit": "g"
#         }
#     },
#     "totalDaily": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 1.5867906433293866,
#             "unit": "%"
#         },
#         "FAT": {
#             "label": "Fat",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "FASAT": {
#             "label": "Saturated",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "CHOCDF": {
#             "label": "Carbs",
#             "quantity": 0.6050455795449775,
#             "unit": "%"
#         },
#         "FIBTG": {
#             "label": "Fiber",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "NA": {
#             "label": "Sodium",
#             "quantity": 0.11096635116654811,
#             "unit": "%"
#         },
#         "CA": {
#             "label": "Calcium",
#             "quantity": 0.02062655384812423,
#             "unit": "%"
#         },
#         "MG": {
#             "label": "Magnesium",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "K": {
#             "label": "Potassium",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "FE": {
#             "label": "Iron",
#             "quantity": 0.01145919658229124,
#             "unit": "%"
#         },
#         "ZN": {
#             "label": "Zinc",
#             "quantity": 0.18751412589203847,
#             "unit": "%"
#         },
#         "P": {
#             "label": "Phosphorus",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "VITC": {
#             "label": "Vitamin C",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "THIA": {
#             "label": "Thiamin (B1)",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "RIBF": {
#             "label": "Riboflavin (B2)",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "NIA": {
#             "label": "Niacin (B3)",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "VITB6A": {
#             "label": "Vitamin B6",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "FOLDFE": {
#             "label": "Folate equivalent (total)",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "VITB12": {
#             "label": "Vitamin B12",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "VITD": {
#             "label": "Vitamin D",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "VITK1": {
#             "label": "Vitamin K",
#             "quantity": 0.0,
#             "unit": "%"
#         }
#     },
#     "totalNutrientsKCal": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 32,
#             "unit": "kcal"
#         },
#         "PROCNT_KCAL": {
#             "label": "Calories from protein",
#             "quantity": 0,
#             "unit": "kcal"
#         },
#         "FAT_KCAL": {
#             "label": "Calories from fat",
#             "quantity": 0,
#             "unit": "kcal"
#         },
#         "CHOCDF_KCAL": {
#             "label": "Calories from carbohydrates",
#             "quantity": 32,
#             "unit": "kcal"
#         }
#     }
# }

# %%
gin_info.keys()
# Out:
# dict_keys(['uri', 'yield', 'calories', 'totalWeight', 'dietLabels', 'healthLabels', 'cautions', 'totalNutrients', 'totalDaily', 'totalNutrientsKCal'])

# %%
print(os.listdir('./'))

# %%
rm_ipynb_recursively('./')
